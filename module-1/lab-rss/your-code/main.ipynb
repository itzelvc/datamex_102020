# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
# import feedparser
import requests
import xmltodict
import re
import pandas as pd

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
data = xmltodict.parse(req.content)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
lis(data.keys())
# Out:
# odict_keys(['rss'])

# %%
print(list(data['rss'].keys()))
# Out:
# ['@xmlns:content', '@xmlns:wfw', '@xmlns:dc', '@xmlns:atom', '@xmlns:sy', '@xmlns:slash', '@xmlns:geo', '@xmlns:feedburner', '@version', 'channel']

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
print(list(data['rss']['channel'].keys()))
# Out:
# ['title', 'link', 'description', 'lastBuildDate', 'language', 'sy:updatePeriod', 'sy:updateFrequency', 'generator', 'atom10:link', 'feedburner:info', 'geo:lat', 'geo:long', 'feedburner:emailServiceId', 'feedburner:feedburnerHostname', 'item']

# %%
# data['rss']['channel']['item']

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
data_item = data['rss']['channel']['item']

# %%
titles = []
subtitles = []
authors = []
links  = []

for i in range(len(data_item))  :
    # Extrayendo el titulo
    titles.append(data_item[i]['title'])
    # Extrayendo el subtitulo
    subtitles.append(data_item[i]['description'].split('&')[0])
    # Extrayendo los autores
    authors.append(data_item[i]['dc:creator'])
    # Extrayendo los links
    links.append(data_item[i]['link'])
    
for i in range(len(titles)):
    print(titles[i], ' | ', subtitles[i], ' | ', authors[i], ' | ', links[0] )
    print('')
# Out:
# Four short links: 28 Oct 2020  |  Phantom of the ADAS   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Our Favorite Questions  |    |  Q Ethan McCallum, Chris Butler and Shane Glynn  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 21 Oct 2020  |  Justice Department Antitrust Filing Against Google   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four Short Links: 16 October 2020  |  Automerge   |  None  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 14 Oct 2020  |  Data Organization in Spreadsheets   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# AI Product Management After Deployment  |  The field of AI product management continues to gain momentum. As the AI product management role advances in maturity, more and more information and advice has become available. Our previous articles in this series introduce our own take on AI product management, discuss the skills that AI product managers need, and detail how to bring [  |  Justin Norman and Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 9 October 2020  |  T-SQL in SQLite   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# AI and Creativity  |  The release of GPT-3 has reinvigorated a discussion of creativity and artificial intelligence. That  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 6 October 2020  |  Algorithms Can Collude   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 2 October 2020  |  Single Device Behaves Like a Neuron   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Radar trends to watch: October 2020  |  This month, the big surprise is that there’s no significant technology news about COVID. And there is more news than ever about legislation and regulation. I suspect that the legal system will be a big driver for technology over the next year. Another trend that doesn’t quite count as technology news but that definitely bears [  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 29 Sep 2020  |  When Coffeemakers Demand Ransom   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 25 September 2020  |  Adapton   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 18 Sep 2020  |  CS349   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 16 Sep 2020  |  A Concurrency Cost Hierarchy   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# How to Set AI Goals  |  AI Benefits and Stakeholders AI is a field where value, in the form of outcomes and their resulting benefits, is created by machines exhibiting the ability to learn and “understand,” and to use the knowledge learned to carry out tasks or achieve goals. AI-generated benefits can be realized by defining and achieving appropriate goals. These [  |  Alex Castrounis  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 11 Sep 2020  |  Accurately Lipsync Video to Any Speech   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 9 Sep 2020  |  Things I Learned to Become a Senior Software Engineer   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Pair Programming with AI  |  In a conversation with Kevlin Henney, we started talking about the kinds of user interfaces that might work for AI-assisted programming. This is a significant problem: neither of us were aware of any significant work on user interfaces that support collaboration. However, as software developers, many of us have been practicing effective collaboration for years. [  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 4 September 2020  |  Inside the Digital Pregnancy Test   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 2 September 2020  |  VSCode Debug Visualizer   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Radar trends to watch: September 2020  |  Compared to the last few months, there are relatively few items about COVID. And almost no items about Blockchains, though the one item I’ve listed, about China’s Blockchain Services Network, may be the most important item here. I’m seeing a steady stream of articles about various forms of no-code/low-code programming. While many programmers scoff at [  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 28 August 2020  |  Activity Watch   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# An Agent of Change  |  The Covid-19 pandemic has changed how people and businesses spend and operate.  |  Q Ethan McCallum and Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 25 August 2020  |  Wooden Turing Machine   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 21 August 2020  |  The 212 Story Tower That Isn  |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four Short Links: 19 August 2020  |  The Design Space of Computational Notebooks   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Why Best-of-Breed is a Better Choice than All-in-One Platforms for Data Science  |  So you need to redesign your company’s data infrastructure. Do you buy a solution from a big integration company like IBM, Cloudera, or Amazon?  |  Matthew Rocklin and Hugo Bowne-Anderson  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 14 August 2020  |  Sinter   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# The Least Liked Programming Languages  |  StackOverflow  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 11 Aug 2020  |  ImmuDB   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 7 Aug 2020  |  Surprising Economics of Load-Balanced Systems   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 5 August 2020  |  Tales of the Autistic Developer   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Radar trends to watch: August 2020  |  I thought July was going to be a dull month, but I’m wrong again. COVID-specific technology seems to be drying up, though there’s a fascinating report about a DIY vaccine. (Developed by serious scientists, so don’t try this at home.) There’s a lot of news about AI, and specifically, about the GPT-2 and GPT-3 language [  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 31 July 2020  |  Migrating a 40TB SQL Server Database   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 30 July 2020  |  Turning the IDE Inside Out with Datalog   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 29 July 2020  |  The Golden Rule of Software Quality   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Bringing an AI Product to Market  |  The Core Responsibilities of the AI Product Manager Product Managers are responsible for the successful development, testing, release, and adoption of a product, and for leading the team that implements those milestones. Product managers for AI must satisfy these same responsibilities, tuned for the AI lifecycle. In the first two articles in this series, we [  |  Justin Norman, Peter Skomoroch and Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Power, Harms, and Data  |  A recent article in The Verge discussed PULSE, an algorithm for “upsampling” digital images. PULSE, when applied to a low-resolution image of Barack Obama, recreated a White man  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 27 July 2020  |  Tech Regulation   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 24 July 2020  |  How Taiwan  |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 26 July 2020  |  As We May Code   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 22 July 2020  |  wiki.js   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# AI, Protests, and Justice  |  Largely on the impetus of the Black Lives Matter movement, the public  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 21 July 2020  |  22 Principles for Great Product Managers   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 20 July 2020  |  A Bug-Sized Camera for Bug-Sized Robots and Bug-Sized Bugs   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 17 July 2020  |  Matters Computational: Ideas, Algorithms, Source Code   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 16 July 2020  |  Pseudogen   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Microservices Adoption in 2020  |  Microservices  |  Mike Loukides and Steve Swoyer  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 15 July 2020  |  Fixing Bugs Properly   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Society-Centered Design  |  A World of Individuals Our world is on fire. For too long we have been complicit, maintaining the status quo. This must change. I’m writing this as we’re living through three pandemics. Covid-19, structurally enabled racism, and the climate crisis. Each of these pandemics make visible the ways that individuals fit into and contribute to [  |  Sarah Gold  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 14 July 2020  |  Neutralizing Misinformation through Inoculation   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 13 July 2020  |  Too Efficiency   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 10 July 2020  |  Notes on Splicing CRDTs for Structured Hypertext   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Automated Coding and the Future of Programming  |  At Microsoft  |  Mike Loukides  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 9 July 2020  |  Avoiding Fallback in Distributed Systems   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 8 July 2020  |  When Data is Messy   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 7 July 2020  |  eDEX-ui   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 6 July 2020  |  Debubble   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/
#
# Four short links: 3 July 2020  |  Open Differential Privacy   |  Nat Torkington  |  http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9SAYsodoeJo/

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(data_item)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
data_item[0].keys()
# Out:
# odict_keys(['title', 'link', 'comments', 'pubDate', 'dc:creator', 'category', 'guid', 'description', 'content:encoded', 'wfw:commentRss', 'slash:comments', 'feedburner:origLink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles
# Out:
# ['Four short links: 28 Oct 2020',
#  'Our Favorite Questions',
#  'Four short links: 21 Oct 2020',
#  'Four Short Links: 16 October 2020',
#  'Four short links: 14 Oct 2020',
#  'AI Product Management After Deployment',
#  'Four short links: 9 October 2020',
#  'AI and Creativity',
#  'Four short links: 6 October 2020',
#  'Four short links: 2 October 2020',
#  'Radar trends to watch: October 2020',
#  'Four short links: 29 Sep 2020',
#  'Four short links: 25 September 2020',
#  'Four short links: 18 Sep 2020',
#  'Four short links: 16 Sep 2020',
#  'How to Set AI Goals',
#  'Four short links: 11 Sep 2020',
#  'Four short links: 9 Sep 2020',
#  'Pair Programming with AI',
#  'Four short links: 4 September 2020',
#  'Four short links: 2 September 2020',
#  'Radar trends to watch: September 2020',
#  'Four short links: 28 August 2020',
#  'An Agent of Change',
#  'Four short links: 25 August 2020',
#  'Four short links: 21 August 2020',
#  'Four Short Links: 19 August 2020',
#  'Why Best-of-Breed is a Better Choice than All-in-One Platforms for Data Science',
#  'Four short links: 14 August 2020',
#  'The Least Liked Programming Languages',
#  'Four short links: 11 Aug 2020',
#  'Four short links: 7 Aug 2020',
#  'Four short links: 5 August 2020',
#  'Radar trends to watch: August 2020',
#  'Four short links: 31 July 2020',
#  'Four short links: 30 July 2020',
#  'Four short links: 29 July 2020',
#  'Bringing an AI Product to Market',
#  'Power, Harms, and Data',
#  'Four short links: 27 July 2020',
#  'Four short links: 24 July 2020',
#  'Four short links: 26 July 2020',
#  'Four short links: 22 July 2020',
#  'AI, Protests, and Justice',
#  'Four short links: 21 July 2020',
#  'Four short links: 20 July 2020',
#  'Four short links: 17 July 2020',
#  'Four short links: 16 July 2020',
#  'Microservices Adoption in 2020',
#  'Four short links: 15 July 2020',
#  'Society-Centered Design',
#  'Four short links: 14 July 2020',
#  'Four short links: 13 July 2020',
#  'Four short links: 10 July 2020',
#  'Automated Coding and the Future of Programming',
#  'Four short links: 9 July 2020',
#  'Four short links: 8 July 2020',
#  'Four short links: 7 July 2020',
#  'Four short links: 6 July 2020',
#  'Four short links: 3 July 2020']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
contador = 0

for i in titles:
    if 'Four short links' in i:
        contador+=1
        
print('Porcentaje:', contador/len(titles) )
# Out:
# Porcentaje: 0.6833333333333333

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame({'title': titles, 'subtitle': subtitles, 'author': authors, 'link':links})
df
# Out:
#                                                 title  \
# 0                       Four short links: 28 Oct 2020
# 1                              Our Favorite Questions
# 2                       Four short links: 21 Oct 2020
# 3                   Four Short Links: 16 October 2020
# 4                       Four short links: 14 Oct 2020
# 5              AI Product Management After Deployment
# 6                    Four short links: 9 October 2020
# 7                                   AI and Creativity
# 8                    Four short links: 6 October 2020
# 9                    Four short links: 2 October 2020
# 10                Radar trends to watch: October 2020
# 11                      Four short links: 29 Sep 2020
# 12                Four short links: 25 September 2020
# 13                      Four short links: 18 Sep 2020
# 14                      Four short links: 16 Sep 2020
# 15                                How to Set AI Goals
# 16                      Four short links: 11 Sep 2020
# 17                       Four short links: 9 Sep 2020
# 18                           Pair Programming with AI
# 19                 Four short links: 4 September 2020
# 20                 Four short links: 2 September 2020
# 21              Radar trends to watch: September 2020
# 22                   Four short links: 28 August 2020
# 23                                 An Agent of Change
# 24                   Four short links: 25 August 2020
# 25                   Four short links: 21 August 2020
# 26                   Four Short Links: 19 August 2020
# 27  Why Best-of-Breed is a Better Choice than All-...
# 28                   Four short links: 14 August 2020
# 29              The Least Liked Programming Languages
# 30                      Four short links: 11 Aug 2020
# 31                       Four short links: 7 Aug 2020
# 32                    Four short links: 5 August 2020
# 33                 Radar trends to watch: August 2020
# 34                     Four short links: 31 July 2020
# 35                     Four short links: 30 July 2020
# 36                     Four short links: 29 July 2020
# 37                   Bringing an AI Product to Market
# 38                             Power, Harms, and Data
# 39                     Four short links: 27 July 2020
# 40                     Four short links: 24 July 2020
# 41                     Four short links: 26 July 2020
# 42                     Four short links: 22 July 2020
# 43                          AI, Protests, and Justice
# 44                     Four short links: 21 July 2020
# 45                     Four short links: 20 July 2020
# 46                     Four short links: 17 July 2020
# 47                     Four short links: 16 July 2020
# 48                     Microservices Adoption in 2020
# 49                     Four short links: 15 July 2020
# 50                            Society-Centered Design
# 51                     Four short links: 14 July 2020
# 52                     Four short links: 13 July 2020
# 53                     Four short links: 10 July 2020
# 54     Automated Coding and the Future of Programming
# 55                      Four short links: 9 July 2020
# 56                      Four short links: 8 July 2020
# 57                      Four short links: 7 July 2020
# 58                      Four short links: 6 July 2020
# 59                      Four short links: 3 July 2020
#
#                                              subtitle  \
# 0                                Phantom of the ADAS
# 1
# 2   Justice Department Antitrust Filing Against Go...
# 3                                          Automerge
# 4                  Data Organization in Spreadsheets
# 5   The field of AI product management continues t...
# 6                                    T-SQL in SQLite
# 7   The release of GPT-3 has reinvigorated a discu...
# 8                             Algorithms Can Collude
# 9                Single Device Behaves Like a Neuron
# 10  This month, the big surprise is that there’s n...
# 11                   When Coffeemakers Demand Ransom
# 12                                           Adapton
# 13                                             CS349
# 14                      A Concurrency Cost Hierarchy
# 15  AI Benefits and Stakeholders AI is a field whe...
# 16            Accurately Lipsync Video to Any Speech
# 17  Things I Learned to Become a Senior Software E...
# 18  In a conversation with Kevlin Henney, we start...
# 19                 Inside the Digital Pregnancy Test
# 20                           VSCode Debug Visualizer
# 21  Compared to the last few months, there are rel...
# 22                                    Activity Watch
# 23  The Covid-19 pandemic has changed how people a...
# 24                             Wooden Turing Machine
# 25                       The 212 Story Tower That Isn
# 26       The Design Space of Computational Notebooks
# 27  So you need to redesign your company’s data in...
# 28                                            Sinter
# 29                                      StackOverflow
# 30                                            ImmuDB
# 31     Surprising Economics of Load-Balanced Systems
# 32                   Tales of the Autistic Developer
# 33  I thought July was going to be a dull month, b...
# 34              Migrating a 40TB SQL Server Database
# 35           Turning the IDE Inside Out with Datalog
# 36               The Golden Rule of Software Quality
# 37  The Core Responsibilities of the AI Product Ma...
# 38  A recent article in The Verge discussed PULSE,...
# 39                                   Tech Regulation
# 40                                         How Taiwan
# 41                                    As We May Code
# 42                                           wiki.js
# 43  Largely on the impetus of the Black Lives Matt...
# 44          22 Principles for Great Product Managers
# 45  A Bug-Sized Camera for Bug-Sized Robots and Bu...
# 46  Matters Computational: Ideas, Algorithms, Sour...
# 47                                         Pseudogen
# 48                                      Microservices
# 49                              Fixing Bugs Properly
# 50  A World of Individuals Our world is on fire. F...
# 51   Neutralizing Misinformation through Inoculation
# 52                                    Too Efficiency
# 53  Notes on Splicing CRDTs for Structured Hypertext
# 54                                       At Microsoft
# 55          Avoiding Fallback in Distributed Systems
# 56                                When Data is Messy
# 57                                           eDEX-ui
# 58                                          Debubble
# 59                         Open Differential Privacy
#
#                                               author  \
# 0                                     Nat Torkington
# 1     Q Ethan McCallum, Chris Butler and Shane Glynn
# 2                                     Nat Torkington
# 3                                               None
# 4                                     Nat Torkington
# 5                    Justin Norman and Mike Loukides
# 6                                     Nat Torkington
# 7                                      Mike Loukides
# 8                                     Nat Torkington
# 9                                     Nat Torkington
# 10                                     Mike Loukides
# 11                                    Nat Torkington
# 12                                    Nat Torkington
# 13                                    Nat Torkington
# 14                                    Nat Torkington
# 15                                   Alex Castrounis
# 16                                    Nat Torkington
# 17                                    Nat Torkington
# 18                                     Mike Loukides
# 19                                    Nat Torkington
# 20                                    Nat Torkington
# 21                                     Mike Loukides
# 22                                    Nat Torkington
# 23                Q Ethan McCallum and Mike Loukides
# 24                                    Nat Torkington
# 25                                    Nat Torkington
# 26                                    Nat Torkington
# 27           Matthew Rocklin and Hugo Bowne-Anderson
# 28                                    Nat Torkington
# 29                                     Mike Loukides
# 30                                    Nat Torkington
# 31                                    Nat Torkington
# 32                                    Nat Torkington
# 33                                     Mike Loukides
# 34                                    Nat Torkington
# 35                                    Nat Torkington
# 36                                    Nat Torkington
# 37  Justin Norman, Peter Skomoroch and Mike Loukides
# 38                                     Mike Loukides
# 39                                    Nat Torkington
# 40                                    Nat Torkington
# 41                                    Nat Torkington
# 42                                    Nat Torkington
# 43                                     Mike Loukides
# 44                                    Nat Torkington
# 45                                    Nat Torkington
# 46                                    Nat Torkington
# 47                                    Nat Torkington
# 48                    Mike Loukides and Steve Swoyer
# 49                                    Nat Torkington
# 50                                        Sarah Gold
# 51                                    Nat Torkington
# 52                                    Nat Torkington
# 53                                    Nat Torkington
# 54                                     Mike Loukides
# 55                                    Nat Torkington
# 56                                    Nat Torkington
# 57                                    Nat Torkington
# 58                                    Nat Torkington
# 59                                    Nat Torkington
#
#                                                  link
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
# 18  http://feedproxy.google.com/~r/oreilly/radar/a...
# 19  http://feedproxy.google.com/~r/oreilly/radar/a...
# 20  http://feedproxy.google.com/~r/oreilly/radar/a...
# 21  http://feedproxy.google.com/~r/oreilly/radar/a...
# 22  http://feedproxy.google.com/~r/oreilly/radar/a...
# 23  http://feedproxy.google.com/~r/oreilly/radar/a...
# 24  http://feedproxy.google.com/~r/oreilly/radar/a...
# 25  http://feedproxy.google.com/~r/oreilly/radar/a...
# 26  http://feedproxy.google.com/~r/oreilly/radar/a...
# 27  http://feedproxy.google.com/~r/oreilly/radar/a...
# 28  http://feedproxy.google.com/~r/oreilly/radar/a...
# 29  http://feedproxy.google.com/~r/oreilly/radar/a...
# 30  http://feedproxy.google.com/~r/oreilly/radar/a...
# 31  http://feedproxy.google.com/~r/oreilly/radar/a...
# 32  http://feedproxy.google.com/~r/oreilly/radar/a...
# 33  http://feedproxy.google.com/~r/oreilly/radar/a...
# 34  http://feedproxy.google.com/~r/oreilly/radar/a...
# 35  http://feedproxy.google.com/~r/oreilly/radar/a...
# 36  http://feedproxy.google.com/~r/oreilly/radar/a...
# 37  http://feedproxy.google.com/~r/oreilly/radar/a...
# 38  http://feedproxy.google.com/~r/oreilly/radar/a...
# 39  http://feedproxy.google.com/~r/oreilly/radar/a...
# 40  http://feedproxy.google.com/~r/oreilly/radar/a...
# 41  http://feedproxy.google.com/~r/oreilly/radar/a...
# 42  http://feedproxy.google.com/~r/oreilly/radar/a...
# 43  http://feedproxy.google.com/~r/oreilly/radar/a...
# 44  http://feedproxy.google.com/~r/oreilly/radar/a...
# 45  http://feedproxy.google.com/~r/oreilly/radar/a...
# 46  http://feedproxy.google.com/~r/oreilly/radar/a...
# 47  http://feedproxy.google.com/~r/oreilly/radar/a...
# 48  http://feedproxy.google.com/~r/oreilly/radar/a...
# 49  http://feedproxy.google.com/~r/oreilly/radar/a...
# 50  http://feedproxy.google.com/~r/oreilly/radar/a...
# 51  http://feedproxy.google.com/~r/oreilly/radar/a...
# 52  http://feedproxy.google.com/~r/oreilly/radar/a...
# 53  http://feedproxy.google.com/~r/oreilly/radar/a...
# 54  http://feedproxy.google.com/~r/oreilly/radar/a...
# 55  http://feedproxy.google.com/~r/oreilly/radar/a...
# 56  http://feedproxy.google.com/~r/oreilly/radar/a...
# 57  http://feedproxy.google.com/~r/oreilly/radar/a...
# 58  http://feedproxy.google.com/~r/oreilly/radar/a...
# 59  http://feedproxy.google.com/~r/oreilly/radar/a...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df['author'].value_counts().to_frame()
# Out:
#                                                   author
# Nat Torkington                                        42
# Mike Loukides                                          9
# Q Ethan McCallum and Mike Loukides                     1
# Mike Loukides and Steve Swoyer                         1
# Alex Castrounis                                        1
# Sarah Gold                                             1
# Justin Norman and Mike Loukides                        1
# Q Ethan McCallum, Chris Butler and Shane Glynn         1
# Justin Norman, Peter Skomoroch and Mike Loukides       1
# Matthew Rocklin and Hugo Bowne-Anderson                1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df1 = df[['title', 'author']].copy()

# Creamos la nueva columna
df1['length_title'] = df1['title'].str.len()

df1.sort_values(by=['length_title'])
# Out:
#                                                 title  \
# 7                                   AI and Creativity
# 23                                 An Agent of Change
# 15                                How to Set AI Goals
# 1                              Our Favorite Questions
# 38                             Power, Harms, and Data
# 50                            Society-Centered Design
# 18                           Pair Programming with AI
# 43                          AI, Protests, and Justice
# 31                       Four short links: 7 Aug 2020
# 17                       Four short links: 9 Sep 2020
# 0                       Four short links: 28 Oct 2020
# 57                      Four short links: 7 July 2020
# 56                      Four short links: 8 July 2020
# 55                      Four short links: 9 July 2020
# 30                      Four short links: 11 Aug 2020
# 58                      Four short links: 6 July 2020
# 59                      Four short links: 3 July 2020
# 14                      Four short links: 16 Sep 2020
# 13                      Four short links: 18 Sep 2020
# 2                       Four short links: 21 Oct 2020
# 4                       Four short links: 14 Oct 2020
# 16                      Four short links: 11 Sep 2020
# 11                      Four short links: 29 Sep 2020
# 41                     Four short links: 26 July 2020
# 36                     Four short links: 29 July 2020
# 35                     Four short links: 30 July 2020
# 34                     Four short links: 31 July 2020
# 42                     Four short links: 22 July 2020
# 44                     Four short links: 21 July 2020
# 45                     Four short links: 20 July 2020
# 46                     Four short links: 17 July 2020
# 47                     Four short links: 16 July 2020
# 48                     Microservices Adoption in 2020
# 49                     Four short links: 15 July 2020
# 51                     Four short links: 14 July 2020
# 52                     Four short links: 13 July 2020
# 53                     Four short links: 10 July 2020
# 39                     Four short links: 27 July 2020
# 40                     Four short links: 24 July 2020
# 32                    Four short links: 5 August 2020
# 6                    Four short links: 9 October 2020
# 8                    Four short links: 6 October 2020
# 9                    Four short links: 2 October 2020
# 28                   Four short links: 14 August 2020
# 26                   Four Short Links: 19 August 2020
# 25                   Four short links: 21 August 2020
# 24                   Four short links: 25 August 2020
# 37                   Bringing an AI Product to Market
# 22                   Four short links: 28 August 2020
# 3                   Four Short Links: 16 October 2020
# 33                 Radar trends to watch: August 2020
# 19                 Four short links: 4 September 2020
# 20                 Four short links: 2 September 2020
# 10                Radar trends to watch: October 2020
# 12                Four short links: 25 September 2020
# 29              The Least Liked Programming Languages
# 21              Radar trends to watch: September 2020
# 5              AI Product Management After Deployment
# 54     Automated Coding and the Future of Programming
# 27  Why Best-of-Breed is a Better Choice than All-...
#
#                                               author  length_title
# 7                                      Mike Loukides            17
# 23                Q Ethan McCallum and Mike Loukides            18
# 15                                   Alex Castrounis            19
# 1     Q Ethan McCallum, Chris Butler and Shane Glynn            22
# 38                                     Mike Loukides            22
# 50                                        Sarah Gold            23
# 18                                     Mike Loukides            24
# 43                                     Mike Loukides            25
# 31                                    Nat Torkington            28
# 17                                    Nat Torkington            28
# 0                                     Nat Torkington            29
# 57                                    Nat Torkington            29
# 56                                    Nat Torkington            29
# 55                                    Nat Torkington            29
# 30                                    Nat Torkington            29
# 58                                    Nat Torkington            29
# 59                                    Nat Torkington            29
# 14                                    Nat Torkington            29
# 13                                    Nat Torkington            29
# 2                                     Nat Torkington            29
# 4                                     Nat Torkington            29
# 16                                    Nat Torkington            29
# 11                                    Nat Torkington            29
# 41                                    Nat Torkington            30
# 36                                    Nat Torkington            30
# 35                                    Nat Torkington            30
# 34                                    Nat Torkington            30
# 42                                    Nat Torkington            30
# 44                                    Nat Torkington            30
# 45                                    Nat Torkington            30
# 46                                    Nat Torkington            30
# 47                                    Nat Torkington            30
# 48                    Mike Loukides and Steve Swoyer            30
# 49                                    Nat Torkington            30
# 51                                    Nat Torkington            30
# 52                                    Nat Torkington            30
# 53                                    Nat Torkington            30
# 39                                    Nat Torkington            30
# 40                                    Nat Torkington            30
# 32                                    Nat Torkington            31
# 6                                     Nat Torkington            32
# 8                                     Nat Torkington            32
# 9                                     Nat Torkington            32
# 28                                    Nat Torkington            32
# 26                                    Nat Torkington            32
# 25                                    Nat Torkington            32
# 24                                    Nat Torkington            32
# 37  Justin Norman, Peter Skomoroch and Mike Loukides            32
# 22                                    Nat Torkington            32
# 3                                               None            33
# 33                                     Mike Loukides            34
# 19                                    Nat Torkington            34
# 20                                    Nat Torkington            34
# 10                                     Mike Loukides            35
# 12                                    Nat Torkington            35
# 29                                     Mike Loukides            37
# 21                                     Mike Loukides            37
# 5                    Justin Norman and Mike Loukides            38
# 54                                     Mike Loukides            46
# 27           Matthew Rocklin and Hugo Bowne-Anderson            79

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
ml_titles = []
for i in range(60):
    
    if 'machine learning' in data_item[i]['content:encoded']:
        
        ml_titles.append(data_item[i]['title'])

ml_titles
# Out:
# ['Our Favorite Questions',
#  'AI Product Management After Deployment',
#  'AI and Creativity',
#  'Radar trends to watch: October 2020',
#  'Four short links: 16 Sep 2020',
#  'How to Set AI Goals',
#  'Radar trends to watch: September 2020',
#  'Why Best-of-Breed is a Better Choice than All-in-One Platforms for Data Science',
#  'Radar trends to watch: August 2020',
#  'Bringing an AI Product to Market',
#  'Power, Harms, and Data',
#  'Four short links: 8 July 2020']
