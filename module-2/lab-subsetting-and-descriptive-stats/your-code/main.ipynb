# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %% [markdown]
# #### Print `temp`

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# **Respuesta**: se tienen 2 columnas tipo string correpondientes a la ciudad y el estado, 1 columna numérica correspondiente a la Temperatura por ciudad.

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
ny_rows = temp[temp.State == 'New York']
ny_rows
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
print('Temperatura promedio de las ciudades de NY:', round(ny_rows.Temperature.mean(),2))
# Out:
# Temperatura promedio de las ciudades de NY: 10.74

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[['City', 'State']].loc[ temp.Temperature > 15 ]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp['City'].loc[ temp.Temperature > 15 ]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp['City'].loc[ (temp.Temperature > 15) & (temp.Temperature < 20) ]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby('State').agg(['mean', 'std'])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee =  pd.read_csv('Employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# **Respuesta:** de las 7 columnas, únicamente 2, _Years_ y _Salary_ , corresponden a columnas numéricas de tipo entero, las columnas restantes son de tipo str.

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022DAF7F8C70>,
# ...
#       dtype=object)

# %% [markdown]
# #### **Salary:**
# - Unicamente un empleado posee un salario de 60.
# - No existen empleadps que tengan salario entre 35 a 55.
#
#
# #### **Years:**
# - El número de años con mayor frecuencia corresponde a 2, seguido por 8.

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
print('Salario promedio:', round(employee.Salary.mean(), 2))
# Out:
# Salario promedio: 48.89

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee[ employee.Salary == employee.Salary.max()]
# Out:
#      Name Department Education Gender Title  Years  Salary
# 6  Carlos         IT    Master      M    VP      8      70
# 8     Ana         HR    Master      F    VP      8      70

# %% [markdown]
# El salario más alto corresponde a 70, los empleados que poseen este salario son Carlos y Ana.

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee[ employee.Salary == employee.Salary.min()]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %% [markdown]
# El salario más bajo corresponde a 30, los empleados que poseen este salario son Maria y David.

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[ employee.Name == 'David' ]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[ employee.Name == 'David' ]['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[ employee.Title == 'associate' ]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[ (employee.Title =='associate') & (employee.Salary > 55) ]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
print('Salario promedio por años de empleamiento:')
employee.groupby('Years').agg({'Salary': np.mean})
# Out:
# Salario promedio por años de empleamiento:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
print('Salario promedio por título:')
employee.groupby('Title').agg({'Salary': np.mean})
# Out:
# Salario promedio por título:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
employee.quantile(.25).to_frame()
# Out:
#         0.25
# Years    2.0
# Salary  35.0

# %%
# print third quartile here
employee.quantile(.75).to_frame()
# Out:
#         0.75
# Years    7.0
# Salary  60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').agg({'Salary' : np.mean })
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# **Respuesta:** La media del salario haciendo distinción por género sí es diferente, la media del salario de mujeres está 2.5 unidades por debajo de la media del salario de los hombres.

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee[['Years', 'Salary']].agg(['min', 'max', 'mean']).T
# Out:
#          min   max       mean
# Years    1.0   8.0   4.111111
# Salary  30.0  70.0  48.888889

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
def dif_max_min(series):
    return series.max() -series.min()

print('Diferencia del máximo salario y el mínimo por departamento')
employee.groupby('Department').agg({'Salary': lambda x: max(x)-min(x)})
# Out:
# Diferencia del máximo salario y el mínimo por departamento
#             Salary
# Department
# HR              40
# IT              40
# Sales            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.csv', index_col=0)
orders.head(3)
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
# 2     536365    84406B  2010     12    3     8
#
#                           Description  Quantity          InvoiceDate  \
# 0  white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                 white metal lantern         6  2010-12-01 08:26:00
# 2      cream cupid hearts coat hanger         8  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     397924 non-null  int64
#  1   StockCode     397924 non-null  object
#  2   year          397924 non-null  int64
#  3   month         397924 non-null  int64
#  4   day           397924 non-null  int64
#  5   hour          397924 non-null  int64
#  6   Description   397924 non-null  object
#  7   Quantity      397924 non-null  int64
#  8   InvoiceDate   397924 non-null  object
#  9   UnitPrice     397924 non-null  float64
#  10  CustomerID    397924 non-null  int64
#  11  Country       397924 non-null  object
#  12  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 42.5+ MB

# %% [markdown]
# De las 13 columnas:
#
# - 9 Son numéricas: sin embargo las columnas 'InvoiceNo', 'CustomerID' son columnas que fungen como ID y por lo tanto pueden ser tratadas como tipo string. También se observa que la fecha viene desagregada en mas columnas: 'year', 'month', 'day' and 'hour'
#
# - 4 columnas son de tipo string

# %%
orders['InvoiceNo'] = orders['InvoiceNo'].astype('str')

orders['CustomerID'] = orders['CustomerID'].astype('str')

# %%
# your answer here
orders.describe()
# Out:
#            InvoiceNo           year          month            day  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   560617.126645    2010.934259       7.612537       3.614555
# std     13106.167695       0.247829       3.416527       1.928274
# min    536365.000000    2010.000000       1.000000       1.000000
# 25%    549234.000000    2011.000000       5.000000       2.000000
# 50%    561893.000000    2011.000000       8.000000       3.000000
# 75%    572090.000000    2011.000000      11.000000       5.000000
# max    581587.000000    2011.000000      12.000000       7.000000
#
#                 hour       Quantity      UnitPrice     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean       12.728247      13.021823       3.116174   15294.315171
# std         2.273535     180.420210      22.096788    1713.169877
# min         6.000000       1.000000       0.000000   12346.000000
# ...

# %% [markdown]
# Del análisis descriptivo del dataframe, observamos que:
# - contiene información de los años 2010 y 2011.
# - Media de Quantity es de 13.02, el precio unitario promedio es de 3.11 y el gasto promedio es de 22.39.
# - Existen facturas con el precio unitario = 0
# - Existen valores muy grandes en las columnas Quantity, UnitPrice, amount_spent, ya que se observa que el máximo para las 3 columnas está muy alejado del cuartil 3.

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
print(round(orders.UnitPrice.mean(), 2))
# Out:
# 3.12

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
print(round(orders.UnitPrice.max(), 2))
# Out:
# 8142.75

# %%
# your answer here
print(round(orders.UnitPrice.min(), 2))
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
customers_spain = orders['CustomerID'].loc[ orders.Country == 'Spain'].unique()
customers_spain
# Out:
# array([12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502,
#        12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417,
#        12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544,
#        12538, 12445, 12442], dtype=int64)

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
len(customers_spain)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
df_customers = orders.groupby('CustomerID').agg({'Quantity': np.sum})
df_customers[ df_customers.Quantity > 50]
# Out:
#             Quantity
# CustomerID
# 12346          74215
# 12347           2458
# 12348           2341
# 12349            631
# 12350            197
# ...              ...
# 18278             66
# 18281             54
# 18282            103
# 18283           1397
# 18287           1586
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[ (orders.Country == 'Spain') & (orders.Quantity  > 50) ]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 6421       536944     22383  2010     12    5    12
# 6422       536944     22384  2010     12    5    12
# 6423       536944     20727  2010     12    5    12
# 6424       536944     20725  2010     12    5    12
# 6425       536944     20728  2010     12    5    12
# 52416      540785    84997B  2011      1    2    11
# 52417      540785    84997D  2011      1    2    11
# 52418      540785    84997C  2011      1    2    11
# 52419      540785    84997A  2011      1    2    11
# 136767     547972     22383  2011      3    1    16
# 136768     547972     22384  2011      3    1    16
# 136771     547972     20728  2011      3    1    16
# 248797     558871     22384  2011      7    1    13
# 248798     558871     20727  2011      7    1    13
# 248799     558871     20725  2011      7    1    13
# 248800     558871     20728  2011      7    1    13
# 248801     558871    84997B  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[ orders.UnitPrice == 0]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 9302       537197     22841  2010     12    7    14
# 33576      539263     22580  2010     12    4    14
# 40089      539722     22423  2010     12    2    13
# 47068      540372     22090  2011      1    4    16
# 47070      540372     22553  2011      1    4    16
# 56674      541109     22168  2011      1    4    15
# 86789      543599    84535B  2011      2    4    13
# 130188     547417     22062  2011      3    3    10
# 139453     548318     22055  2011      3    3    12
# 145208     548871     22162  2011      4    1    14
# 157042     550188     22636  2011      4    4    18
# 187613     553000     47566  2011      5    4    15
# 198383     554037     22619  2011      5    5    14
# 279324     561284     22167  2011      7    2    12
# 282912     561669     22960  2011      7    4    17
# 285657     561916         M  2011      8    1    11
# 298054     562973     23157  2011      8    4    11
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[['InvoiceNo', 'Description']].loc[ orders['Description'].apply(lambda x: 'lunch bag' in x ) ]
# Out:
#         InvoiceNo                  Description
# 93         536378      lunch bag red retrospot
# 174        536385  lunch bag dolly girl design
# 363        536401  lunch bag dolly girl design
# 368        536401      lunch bag red retrospot
# 369        536401   lunch bag spaceboy design
# ...           ...                          ...
# 540436     581486    lunch bag alphabet design
# 541695     581538      lunch bag  black skull.
# 541696     581538      lunch bag red retrospot
# 541862     581581  lunch bag red vintage doily
# 541865     581583      lunch bag red retrospot
#
# [11556 rows x 2 columns]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[['InvoiceNo', 'year', 'Description']].loc[ (orders['Description'].apply(lambda x: 'lunch bag' in x )) 
                                                 & (orders.year==2011) ]
# Out:
#         InvoiceNo  year                  Description
# 42678      540015  2011      lunch bag red retrospot
# 42679      540015  2011           lunch bag woodland
# 42851      540023  2011   lunch bag spaceboy design
# 42852      540023  2011           lunch bag woodland
# 43616      540098  2011      lunch bag pink polkadot
# ...           ...   ...                          ...
# 540436     581486  2011    lunch bag alphabet design
# 541695     581538  2011      lunch bag  black skull.
# 541696     581538  2011      lunch bag red retrospot
# 541862     581581  2011  lunch bag red vintage doily
# 541865     581583  2011      lunch bag red retrospot
#
# [11234 rows x 3 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
orders[['Country', 'amount_spent']].loc[ orders.Country == 'Spain'].hist( bins=50);

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[ orders.month==8]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 285421     561904     22075  2011      8    1     8
# 285422     561904    85049E  2011      8    1     8
# 285423     561905     21385  2011      8    1     9
# 285424     561905    84970L  2011      8    1     9
# 285425     561905    84970S  2011      8    1     9
# ...           ...       ...   ...    ...  ...   ...
# 320688     565067     22644  2011      8    3    17
# 320689     565067     22645  2011      8    3    17
# 320690     565067     22637  2011      8    3    17
# 320691     565067     22646  2011      8    3    17
# 320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 285421         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 285422            scandinavian reds ribbons       156  2011-08-01 08:30:00
# 285423      ivory hanging decoration  heart        24  2011-08-01 09:31:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders[['InvoiceNo', 'Country']].groupby('Country').count()
# Out:
#                       InvoiceNo
# Country
# Australia                  1185
# Austria                     398
# Bahrain                      17
# Belgium                    2031
# Brazil                       32
# Canada                      151
# Channel Islands             748
# Cyprus                      614
# Czech Republic               25
# Denmark                     380
# EIRE                       7238
# European Community           60
# Finland                     685
# France                     8342
# Germany                    9042
# Greece                      145
# Iceland                     182
# Israel                      248
# Italy                       758
# Japan                       321
# Lebanon                      45
# Lithuania                    35
# Malta                       112
# Netherlands                2363
# Norway                     1072
# Poland                      330
# Portugal                   1462
# RSA                          58
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby('Country').agg({'amount_spent': np.mean})
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders[ orders.UnitPrice == orders.UnitPrice.max() ]
# Out:
#         InvoiceNo StockCode  year  month  day  hour Description  Quantity  \
# 173382     551697      POST  2011      5    2    13     postage         1
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  \
# 173382  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 173382       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby('year').agg({'amount_spent': np.mean})
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
